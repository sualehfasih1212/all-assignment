# %%
a=int(input())
b=int(input())
c=a + b
print(c)
# Out:
# 2
# 3
# 5

# %%
print("hello,world!")
# Out:
# hello,world!

# %%
name="marks"
print(name)
# Out:
# marks

# %%
last_name = "Smith" 
city_of_origin = "New Orleans"
print(last_name)
# Out:
# Smith

# %%
print("hello , world!")
# Out:
# hello , world!

# %%
original_num=139
new_num=original_num + 11
print(new_num)
# Out:
# 150

# %%
print(2 + 2)
# Out:
# 4

# %%
popular_number = 12 / 4
print(popular_number )
# Out:
# 3.0

# %%
whats_left_over = 9 % 3
print(whats_left_over)
# Out:
# 0

# %%
age += 50
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-90de2b7853c4> in <module>
# ----> 1 age += 50
#
# NameError: name 'age' is not defined

# %%
age=39
age += 50
print(age)
# Out:
# 89

# %%
sualeh="saleh"
sep=""
f_name="muhammad fasih"
c= sualeh + sep + f_name
print(c)
# Out:
# salehmuhammad fasih

# %%
print("the sum of two is" + "4")
# Out:
# the sum of two is4

# %%
age=int(input())
if age > 18 :
print("you are younger")
# Out:
#   File "<ipython-input-38-ff328a9180a7>", line 3
#     print("you are younger")
#         ^
# IndentationError: expected an indented block

# %%
species=input()
if species != "cat":   
    print("Yep, it's not a cat.")
# Out:
# dog
# Yep, it's not a cat.

# %%
a=input()
if a == "sualeh":
    print("you are muslim")
# Out:
# sualeh
# you are muslim

# %%
if weight > 300 and time < 6: 
    status = "try to recruit him"
# Out:
#   File "<ipython-input-50-50ac6a42840e>", line 2
#     if age > 18 a="you are Above 19":
#                 ^
# SyntaxError: invalid syntax

# %%
age=int(input())
if age >= 18:
    print("you are   ty")
